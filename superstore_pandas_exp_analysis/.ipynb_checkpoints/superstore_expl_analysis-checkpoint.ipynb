# %%
# To do: 

# Drop Cloumns
# Date Modification
# Price Correction
# String conversion

# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import datetime as dt
import numpy as np

#  Import and read the file:
import pandas as pd 
super_df = pd.read_csv("resources/Global Superstore Orders 2016.csv")
super_df.head()
# Out:
#    Row ID                  Order ID Order Date Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954   11/11/14  11/13/14   First Class
# 1   26341    IN-2014-JR162107-41675     2/5/14    2/7/14  Second Class
# 2   25330    IN-2014-CR127307-41929   10/17/14  10/18/14   First Class
# 3   13524   ES-2014-KM1637548-41667    1/28/14   1/30/14   First Class
# 4   47221   SG-2014-RH9495111-41948    11/5/14   11/6/14      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
# drop nonessential columns
super_df_drop = super_df.drop(["Row ID", "Order ID","Postal Code", "Discount", "Customer ID", "Customer Name", ], 1)
super_df_drop.head()
# Out:
# /Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#   Order Date Ship Date     Ship Mode      Segment           City  \
# 0   11/11/14  11/13/14   First Class     Consumer  Oklahoma City
# 1     2/5/14    2/7/14  Second Class    Corporate     Wollongong
# 2   10/17/14  10/18/14   First Class     Consumer       Brisbane
# 3    1/28/14   1/30/14   First Class  Home Office         Berlin
# 4    11/5/14   11/6/14      Same Day     Consumer          Dakar
#
#              State        Country          Region        Market   Product ID  \
# 0         Oklahoma  United States      Central US          USCA  TEC-PH-5816
# 1  New South Wales      Australia         Oceania  Asia Pacific  FUR-CH-5379
# ...

# %%
# Determine the number of unique values in each column.
super_df_drop.nunique()
# Out:
# Order Date         1430
# Ship Date          1464
# Ship Mode             4
# Segment               3
# City               3650
# State              1102
# Country             165
# Region               23
# Market                5
# Product ID         3788
# Category              3
# Sub-Category         17
# Product Name       3788
# Sales             20049
# Quantity             14
# Profit            16578
# Shipping Cost     16452
# Order Priority        4
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_count = app_df_drop.APPLICATION_TYPE.value_counts()
app_type_count
