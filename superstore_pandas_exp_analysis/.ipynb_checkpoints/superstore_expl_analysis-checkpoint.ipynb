# %%
# Will need to: 

# Drop Cloumns
# Date Modification
# Price Correction
# String conversion

# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the file:
import pandas as pd 
sup_df = pd.read_csv("resources/Global Superstore Orders 2016.csv")
sup_df.head()
# Out:
#   File "/var/folders/ys/dtrr5c7x3qg0zys2rj8gf9yw0000gn/T/ipykernel_87396/667462091.py", line 1
#     Will need to
#             ^
# SyntaxError: invalid syntax

# %%
# Drop the non-beneficial columns
app_df_drop = sup_df.drop(["Row ID", "Order ID","Postal Code", "Discount", "Customer ID"], 1)
app_df_drop
# Out:
# /Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#       Order Date Ship Date       Ship Mode   Customer ID       Customer Name  \
# 0       11/11/14  11/13/14     First Class  AB-100151402       Aaron Bergman
# 1         2/5/14    2/7/14    Second Class     JR-162107       Justin Ritter
# 2       10/17/14  10/18/14     First Class     CR-127307        Craig Reiter
# 3        1/28/14   1/30/14     First Class    KM-1637548    Katherine Murray
# 4        11/5/14   11/6/14        Same Day    RH-9495111         Rick Hansen
# ...          ...       ...             ...           ...                 ...
# 51285    6/19/15   6/19/15        Same Day    KE-1642066     Katrina Edelman
# 51286     5/6/14   5/10/14  Standard Class  ZD-219251408  Zuschuss Donatelli
# 51287    8/26/12   8/31/12    Second Class  ZD-219251404  Zuschuss Donatelli
# 51288    2/17/13   2/21/13  Standard Class    RB-1979518          Ross Baird
# 51289    5/22/13   5/26/13    Second Class    MC-1810093       Mick Crebagga
#
#            Segment           City            State        Country  \
# 0         Consumer  Oklahoma City         Oklahoma  United States
# 1        Corporate     Wollongong  New South Wales      Australia
# 2         Consumer       Brisbane       Queensland      Australia
# 3      Home Office         Berlin           Berlin        Germany
# 4         Consumer          Dakar            Dakar        Senegal
# ...            ...            ...              ...            ...
# 51285    Corporate           Kure        Hiroshima          Japan
# 51286     Consumer    Chattanooga        Tennessee  United States
# 51287     Consumer  San Francisco       California  United States
# 51288  Home Office       Valinhos        São Paulo         Brazil
# 51289     Consumer       Tipitapa          Managua      Nicaragua
#
#                 Region        Market   Product ID         Category  \
# 0           Central US          USCA  TEC-PH-5816       Technology
# 1              Oceania  Asia Pacific  FUR-CH-5379        Furniture
# 2              Oceania  Asia Pacific  TEC-PH-5356       Technology
# 3       Western Europe        Europe  TEC-PH-5267       Technology
# 4       Western Africa        Africa  TEC-CO-6011       Technology
# ...                ...           ...          ...              ...
# 51285     Eastern Asia  Asia Pacific  OFF-FA-3072  Office Supplies
# 51286      Southern US          USCA  FUR-FU-4070        Furniture
# 51287       Western US          USCA  OFF-AR-5321  Office Supplies
# 51288    South America         LATAM  OFF-BI-2919  Office Supplies
# 51289  Central America         LATAM  OFF-PA-3990  Office Supplies
#
#       Sub-Category                                   Product Name      Sales  \
# 0           Phones                               Samsung Convoy 3    $221.98
# 1           Chairs      Novimex Executive Leather Armchair, Black  $3,709.40
# 2           Phones              Nokia Smart Phone, with Caller ID  $5,175.17
# 3           Phones                 Motorola Smart Phone, Cordless  $2,892.51
# 4          Copiers                 Sharp Wireless Fax, High-Speed  $2,832.96
# ...            ...                                            ...        ...
# 51285    Fasteners                  Advantus Thumb Tacks, 12 Pack     $65.10
# 51286  Furnishings  Eldon Image Series Desk Accessories, Burgundy     $16.72
# 51287          Art                                     Newell 341      $8.56
# 51288      Binders                        Acco Index Tab, Economy     $13.44
# 51289        Paper        Eaton Computer Printout Paper, 8.5 x 11     $61.38
#
#        Quantity    Profit  Shipping Cost Order Priority
# 0             2    $62.15         40.770           High
# 1             9  -$288.77        923.630       Critical
# 2             9   $919.97        915.490         Medium
# 3             5   -$96.54        910.160         Medium
# 4             8   $311.52        903.040       Critical
# ...         ...       ...            ...            ...
# 51285         5     $4.50          1.010         Medium
# 51286         5     $3.34          1.930           High
# 51287         2     $2.48          1.580           High
# 51288         2     $2.40          1.003         Medium
# 51289         3     $1.80          1.002           High
#
# [51290 rows x 20 columns]
