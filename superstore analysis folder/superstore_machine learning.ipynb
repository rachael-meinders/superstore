# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import tensorflow as tf
from sklearn.metrics import r2_score
import pandas as pd
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense

# %%
#  Import and read the file:
df = pd.read_csv("resources/encoded_ss_df.csv", index_col=[0])
df.head()
# Out:
#    City  State  Country  Region  Market    Sales  Quantity  Discount  Profit  \
# 0  2369    754      156       5       4   221.98         2       0.0   62.15
# 1  3532    709        6      12       1  3709.40         9       0.1 -288.77
# 2   499    828        6      12       1  5175.17         9       0.1  919.97
# 3   376    148       54      21       2  2892.51         5       0.1  -96.54
# 4   859    276      124      19       0  2832.96         8       0.0  311.52
#
#    Shipping_Cost  ...  Sub_Category_Storage  Sub_Category_Supplies  \
# 0          40.77  ...                     0                      0
# 1         923.63  ...                     0                      0
# 2         915.49  ...                     0                      0
# 3         910.16  ...                     0                      0
# 4         903.04  ...                     0                      0
#
#    Sub_Category_Tables  Category_Furniture  Category_Office Supplies  \
# 0                    0                   0                         0
# 1                    0                   1                         0
# 2                    0                   0                         0
# 3                    0                   0                         0
# 4                    0                   0                         0
#
#    Category_Technology  Order Priority_Critical  Order Priority_High  \
# 0                    1                        0                    1
# 1                    0                        1                    0
# 2                    1                        0                    0
# 3                    1                        0                    0
# 4                    1                        1                    0
#
#    Order Priority_Low  Order Priority_Medium
# 0                   0                      0
# 1                   0                      0
# 2                   0                      1
# 3                   0                      1
# 4                   0                      0
#
# [5 rows x 47 columns]

# %%
df = df.drop(['City', 'State', 'Country', 'Region','Market'], 1)
df.head()
# Out:
# /Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#      Sales  Quantity  Discount  Profit  Shipping_Cost  order_year  \
# 0   221.98         2       0.0   62.15          40.77        2014
# 1  3709.40         9       0.1 -288.77         923.63        2014
# 2  5175.17         9       0.1  919.97         915.49        2014
# 3  2892.51         5       0.1  -96.54         910.16        2014
# 4  2832.96         8       0.0  311.52         903.04        2014
#
#    order_month  order_day  ship_year  ship_month  ...  Sub_Category_Storage  \
# 0           11         11       2014          11  ...                     0
# 1            2          5       2014           2  ...                     0
# 2           10         17       2014          10  ...                     0
# 3            1         28       2014           1  ...                     0
# 4           11          5       2014          11  ...                     0
#
#    Sub_Category_Supplies  Sub_Category_Tables  Category_Furniture  \
# 0                      0                    0                   0
# 1                      0                    0                   1
# 2                      0                    0                   0
# 3                      0                    0                   0
# 4                      0                    0                   0
#
#    Category_Office Supplies  Category_Technology  Order Priority_Critical  \
# 0                         0                    1                        0
# 1                         0                    0                        1
# 2                         0                    1                        0
# 3                         0                    1                        0
# 4                         0                    1                        1
#
#    Order Priority_High  Order Priority_Low  Order Priority_Medium
# 0                    1                   0                      0
# 1                    0                   0                      0
# 2                    0                   0                      1
# 3                    0                   0                      1
# 4                    0                   0                      0
#
# [5 rows x 42 columns]

# %%
y = df['Sales']
X = df.drop('Sales',axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, shuffle=True, random_state = 1)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test),columns = X.columns)

# %%
X_train.describe()
# Out:
#            Quantity      Discount        Profit  Shipping_Cost    order_year  \
# count  3.590300e+04  3.590300e+04  3.590300e+04   3.590300e+04  3.590300e+04
# mean   1.294857e-15 -3.870798e-16 -1.652130e-17  -9.357254e-18 -5.198092e-14
# std    1.000014e+00  1.000014e+00  1.000014e+00   1.000014e+00  1.000014e+00
# min   -1.084277e+00 -6.749629e-01 -4.005773e+01  -4.428285e-01 -1.615668e+00
# 25%   -6.449299e-01 -6.749629e-01 -1.688932e-01  -4.143975e-01 -7.069607e-01
# 50%   -2.055827e-01 -6.749629e-01 -1.130486e-01  -3.242546e-01  2.017465e-01
# 75%    6.731119e-01  2.702535e-01  4.961974e-02  -3.906568e-02  1.110454e+00
# max    4.627237e+00  3.342207e+00  3.029170e+01   1.594399e+01  1.110454e+00
#
#         order_month     order_day     ship_year    ship_month      ship_day  \
# count  3.590300e+04  3.590300e+04  3.590300e+04  3.590300e+04  3.590300e+04
# mean   1.466578e-16 -3.796398e-17  9.067217e-14  1.269074e-16 -1.417465e-16
# std    1.000014e+00  1.000014e+00  1.000014e+00  1.000014e+00  1.000014e+00
# min   -1.979249e+00 -1.686595e+00 -1.618215e+00 -1.938137e+00 -1.679875e+00
# 25%   -7.648532e-01 -8.880841e-01 -7.157096e-01 -7.393629e-01 -8.876411e-01
# 50%    1.459436e-01  2.449981e-02  1.867954e-01  1.597174e-01  1.776940e-02
# 75%    7.531415e-01  8.230108e-01  1.089300e+00  7.591043e-01  8.100036e-01
# max    1.360339e+00  1.735595e+00  1.991805e+00  1.358491e+00  1.715414e+00
#
#        ...  Sub_Category_Storage  Sub_Category_Supplies  Sub_Category_Tables  \
# count  ...          3.590300e+04           3.590300e+04         3.590300e+04
# mean   ...         -4.394610e-15           2.115335e-15         6.662761e-16
# std    ...          1.000014e+00           1.000014e+00         1.000014e+00
# min    ...         -3.299030e-01          -2.198968e-01        -1.336439e-01
# 25%    ...         -3.299030e-01          -2.198968e-01        -1.336439e-01
# 50%    ...         -3.299030e-01          -2.198968e-01        -1.336439e-01
# 75%    ...         -3.299030e-01          -2.198968e-01        -1.336439e-01
# max    ...          3.031194e+00           4.547588e+00         7.482572e+00
#
#        Category_Furniture  Category_Office Supplies  Category_Technology  \
# count        3.590300e+04              3.590300e+04         3.590300e+04
# mean         1.110775e-15             -1.927390e-15        -3.994644e-16
# std          1.000014e+00              1.000014e+00         1.000014e+00
# min         -4.860494e-01             -1.257636e+00        -4.941351e-01
# 25%         -4.860494e-01             -1.257636e+00        -4.941351e-01
# 50%         -4.860494e-01              7.951423e-01        -4.941351e-01
# 75%         -4.860494e-01              7.951423e-01        -4.941351e-01
# max          2.057404e+00              7.951423e-01         2.023738e+00
#
#        Order Priority_Critical  Order Priority_High  Order Priority_Low  \
# count             3.590300e+04         3.590300e+04        3.590300e+04
# mean             -3.701552e-15        -6.022163e-16       -2.336418e-15
# std               1.000014e+00         1.000014e+00        1.000014e+00
# min              -2.872704e-01        -6.606983e-01       -2.209388e-01
# 25%              -2.872704e-01        -6.606983e-01       -2.209388e-01
# 50%              -2.872704e-01        -6.606983e-01       -2.209388e-01
# 75%              -2.872704e-01         1.513550e+00       -2.209388e-01
# max               3.481041e+00         1.513550e+00        4.526139e+00
#
#        Order Priority_Medium
# count           3.590300e+04
# mean           -2.176672e-15
# std             1.000014e+00
# min            -1.159243e+00
# 25%            -1.159243e+00
# 50%             8.626321e-01
# 75%             8.626321e-01
# max             8.626321e-01
#
# [8 rows x 41 columns]

# %%
X_train.columns
# Out:
# Index(['Quantity', 'Discount', 'Profit', 'Shipping_Cost', 'order_year',
#        'order_month', 'order_day', 'ship_year', 'ship_month', 'ship_day',
#        'Ship_Mode_First Class', 'Ship_Mode_Same Day', 'Ship_Mode_Second Class',
#        'Ship_Mode_Standard Class', 'Segment_Consumer', 'Segment_Corporate',
#        'Segment_Home Office', 'Sub_Category_Accessories',
#        'Sub_Category_Appliances', 'Sub_Category_Art', 'Sub_Category_Binders',
#        'Sub_Category_Bookcases', 'Sub_Category_Chairs', 'Sub_Category_Copiers',
#        'Sub_Category_Envelopes', 'Sub_Category_Fasteners',
#        'Sub_Category_Furnishings', 'Sub_Category_Labels',
#        'Sub_Category_Machines', 'Sub_Category_Paper', 'Sub_Category_Phones',
#        'Sub_Category_Storage', 'Sub_Category_Supplies', 'Sub_Category_Tables',
#        'Category_Furniture', 'Category_Office Supplies', 'Category_Technology',
#        'Order Priority_Critical', 'Order Priority_High', 'Order Priority_Low',
#        'Order Priority_Medium'],
#       dtype='object')

# %%
# Training
X_train.shape
# Out:
# (35903, 41)

# %%
inputs = tf.keras.Input(shape=(X_train.shape[1],))
x = tf.keras.layers.Dense(128, activation='relu')(inputs)
x = tf.keras.layers.Dense(128, activation='relu')(x)
outputs = tf.keras.layers.Dense(1,activation='linear')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 41)]              0
#
#  dense (Dense)               (None, 128)               5376
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 22,017
# Trainable params: 22,017
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2022-02-26 19:54:24.705755: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(
    optimizer='adam',
    loss='mse'
)

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=32,
    epochs=100,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau()
    ]
)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ys/dtrr5c7x3qg0zys2rj8gf9yw0000gn/T/ipykernel_2964/1347969377.py in <module>
#      16             restore_best_weights=True
#      17         ),
# ---> 18         tf.keras.callbacks.ReduceLROnPlateau()
#      19     ]
#      20 )
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# -> 1129               raise e.ag_error_metadata.to_exception(e)
#    1130             else:
#    1131               raise
#
# AttributeError: in user code:
#
#     File "/Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/keras/engine/training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/keras/engine/training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/keras/engine/training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/keras/engine/training.py", line 863, in train_step
#         self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py", line 532, in minimize
#         return self.apply_gradients(grads_and_vars, name=name)
#     File "/Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py", line 668, in apply_gradients
#         grads_and_vars = self._aggregate_gradients(grads_and_vars)
#     File "/Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py", line 484, in _aggregate_gradients
#         return self.gradient_aggregator(grads_and_vars)
#     File "/Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/keras/optimizer_v2/utils.py", line 33, in all_reduce_sum_gradients
#         if tf.__internal__.distribute.strategy_supports_no_merge_call():
#
#     AttributeError: module 'tensorflow.compat.v2.__internal__.distribute' has no attribute 'strategy_supports_no_merge_call'
