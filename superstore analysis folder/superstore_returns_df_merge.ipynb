# %%
# not ready to merge until return data is checked and cleaned in other ipynb file
# import packages
import pandas as pd

# %%
# Import and read the file:
df1 = pd.read_csv("resources/global_superstore_returns.csv")
df2 = pd.read_csv("resources/superstore_cleaned_with_OrderID.csv", index_col=[0])
df1.head(3)
# Out:
#   Returned                  Order ID        Region
# 0      Yes  CA-2012-SA20830140-41210    Central US
# 1      Yes  IN-2012-PB19210127-41259  Eastern Asia
# 2      Yes  CA-2012-SC20095140-41174    Central US

# %%
df2.head(3)
# Out:
#                    Order ID  Order_Date   Ship_Date     Ship_Mode    Segment  \
# 0  CA-2014-AB10015140-41954  2014-11-11  2014-11-13   First Class   Consumer
# 1    IN-2014-JR162107-41675  2014-02-05  2014-02-07  Second Class  Corporate
# 2    IN-2014-CR127307-41929  2014-10-17  2014-10-18   First Class   Consumer
#
#             City            State        Country      Region        Market  \
# 0  Oklahoma City         Oklahoma  United States  Central US          USCA
# 1     Wollongong  New South Wales      Australia     Oceania  Asia Pacific
# 2       Brisbane       Queensland      Australia     Oceania  Asia Pacific
#
#      Category Sub_Category                               Product_Name  \
# 0  Technology       Phones                           Samsung Convoy 3
# 1   Furniture       Chairs  Novimex Executive Leather Armchair, Black
# 2  Technology       Phones          Nokia Smart Phone, with Caller ID
#
#      Sales  Quantity  Discount  Profit  Shipping_Cost Order Priority
# ...

# %%
# pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None,
#          left_index=False, right_index=False, sort=True,
#          suffixes=('_x', '_y'), copy=True, indicator=False,
#          validate=None)
df3_merged = pd.merge(df1, df2, on=["Order ID", "Order ID"])
df3_merged.head()
# Out:
#   Returned                  Order ID      Region_x  Order_Date   Ship_Date  \
# 0      Yes  CA-2012-SA20830140-41210    Central US  2012-10-28  2012-10-30
# 1      Yes  IN-2012-PB19210127-41259  Eastern Asia  2012-12-16  2012-12-19
# 2      Yes  IN-2012-PB19210127-41259  Eastern Asia  2012-12-16  2012-12-19
# 3      Yes  IN-2012-PB19210127-41259  Eastern Asia  2012-12-16  2012-12-19
# 4      Yes  IN-2012-PB19210127-41259  Eastern Asia  2012-12-16  2012-12-19
#
#      Ship_Mode    Segment     City        State        Country  ...  \
# 0  First Class   Consumer  Chicago     Illinois  United States  ...
# 1  First Class  Corporate   Taipei  Taipei City         Taiwan  ...
# 2  First Class  Corporate   Taipei  Taipei City         Taiwan  ...
# 3  First Class  Corporate   Taipei  Taipei City         Taiwan  ...
# 4  First Class  Corporate   Taipei  Taipei City         Taiwan  ...
#
#          Market    Category Sub_Category  \
# 0          USCA  Technology       Phones
# ...

# %%
df3_merged["Order ID"].count()
# Out:
# 2220

# %%
# save merged dataframe to resources folder
df3_merged.to_csv("resources/merged_ss.csv")
