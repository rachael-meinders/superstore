# %%
# Clean the data and remove unneccesary columns
# To do: 

# Drop Cloumns
# Date Modification
# Price Correction


import datetime as dt
import numpy as np
import pandas as pd

#  Import and read the file:
super_df = pd.read_csv("resources/Global Superstore Orders 2016.csv")
super_df.head()
# Out:
#    Row ID                  Order ID Order Date Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954   11/11/14  11/13/14   First Class
# 1   26341    IN-2014-JR162107-41675     2/5/14    2/7/14  Second Class
# 2   25330    IN-2014-CR127307-41929   10/17/14  10/18/14   First Class
# 3   13524   ES-2014-KM1637548-41667    1/28/14   1/30/14   First Class
# 4   47221   SG-2014-RH9495111-41948    11/5/14   11/6/14      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
#checking the shape of the dataset
super_df.shape
# Out:
# (51290, 24)

# %%
super_df.describe()
# Out:
#             Row ID   Postal Code      Quantity      Discount  Shipping Cost
# count  51290.00000   9994.000000  51290.000000  51290.000000   51290.000000
# mean   25645.50000  55190.379428      3.476545      0.142908      26.478567
# std    14806.29199  32063.693350      2.278766      0.212280      57.251373
# min        1.00000   1040.000000      1.000000      0.000000       1.002000
# 25%    12823.25000  23223.000000      2.000000      0.000000       2.610000
# 50%    25645.50000  56430.500000      3.000000      0.000000       7.790000
# 75%    38467.75000  90008.000000      5.000000      0.200000      24.450000
# max    51290.00000  99301.000000     14.000000      0.850000     933.570000

# %%
# check for missing values
print(super_df.isnull().sum())
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
# Determine the number of unique values in each column.
super_df.nunique()
# Out:
# Row ID            51290
# Order ID          25728
# Order Date         1430
# Ship Date          1464
# Ship Mode             4
# Customer ID       17415
# Customer Name       796
# Segment               3
# Postal Code         631
# City               3650
# State              1102
# Country             165
# Region               23
# Market                5
# Product ID         3788
# Category              3
# Sub-Category         17
# Product Name       3788
# Sales             20049
# Quantity             14
# Discount             27
# Profit            16578
# Shipping Cost     16452
# Order Priority        4
# dtype: int64

# %%
#Checking if any duplicate row is there in the dataset
super_df.duplicated().sum()
# Out:
# 0

# %%
# look at data types
super_df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Postal Code       float64
# City               object
# State              object
# Country            object
# Region             object
# Market             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales              object
# Quantity            int64
# Discount          float64
# Profit             object
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
# fix sales data type
super_df['Sales'] = super_df['Sales'].str.replace(',', '')
super_df['Sales'] = super_df['Sales'].str.replace('$', '')
super_df['Sales'] = super_df['Sales'].astype(float)
# Out:
# /Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# fix profit data type
super_df['Profit'] = super_df['Profit'].str.replace(',', '')
super_df['Profit'] = super_df['Profit'].str.replace('$', '')
super_df['Profit'] = super_df['Profit'].astype(float)
# Out:
# /Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# fix date time dtypes in ship date and order date

super_df['Order Date']= pd.to_datetime(super_df['Order Date'])
super_df['Ship Date']= pd.to_datetime(super_df['Ship Date'])

# %%
super_df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
#check data types
super_df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
# rename columns with spaces for easier manipulation

# df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'}, inplace=True)
super_df.rename(columns={'Sub-Category': 'Sub_Category', 'Shipping Cost':'Shipping_Cost', 'Order Date':'Order_Date','Ship Date': 'Ship_Date', 'Ship Mode':'Ship_Mode', 'Product Name':'Product_Name'}, inplace=True)
super_df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub_Category', 'Product_Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping_Cost', 'Order Priority'],
#       dtype='object')

# %%
# drop columns 
# Row ID,Order ID,Customer ID,Customer Name,Postal Code,Product ID all dropped
df_drop = super_df.drop(['Row ID','Order ID','Customer ID','Customer Name','Postal Code','Product ID'], 1)
df_drop.head()
# Out:
# /Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Order_Date  Ship_Date     Ship_Mode      Segment           City  \
# 0 2014-11-11 2014-11-13   First Class     Consumer  Oklahoma City
# 1 2014-02-05 2014-02-07  Second Class    Corporate     Wollongong
# 2 2014-10-17 2014-10-18   First Class     Consumer       Brisbane
# 3 2014-01-28 2014-01-30   First Class  Home Office         Berlin
# 4 2014-11-05 2014-11-06      Same Day     Consumer          Dakar
#
#              State        Country          Region        Market    Category  \
# 0         Oklahoma  United States      Central US          USCA  Technology
# 1  New South Wales      Australia         Oceania  Asia Pacific   Furniture
# ...

# %%
# put cleaned dataframe into new csv in resources folder for further analysis
df_drop.to_csv("resources/cleaned_superstore_data.csv")

# %%
# make separate df with order id set as index
df_drop_orderid = super_df.drop(['Row ID','Customer ID','Customer Name','Postal Code','Product ID'], 1)
order_id_df = df_drop_orderid.set_index('Order ID')
order_id_df.head(5)
# Out:
# /Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#                          Order_Date  Ship_Date     Ship_Mode      Segment  \
# Order ID
# CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class     Consumer
# IN-2014-JR162107-41675   2014-02-05 2014-02-07  Second Class    Corporate
# IN-2014-CR127307-41929   2014-10-17 2014-10-18   First Class     Consumer
# ES-2014-KM1637548-41667  2014-01-28 2014-01-30   First Class  Home Office
# SG-2014-RH9495111-41948  2014-11-05 2014-11-06      Same Day     Consumer
#
#                                    City            State        Country  \
# Order ID
# CA-2014-AB10015140-41954  Oklahoma City         Oklahoma  United States
# IN-2014-JR162107-41675       Wollongong  New South Wales      Australia
# ...

# %%
# save new dataframe to resources folder
order_id_df.to_csv("resources/ss_cleaned_orderid_index.csv")
