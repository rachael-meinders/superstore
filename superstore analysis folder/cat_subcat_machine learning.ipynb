# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import tensorflow as tf
from sklearn.metrics import r2_score
import pandas as pd
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
#  Import and read the file:
df = pd.read_csv("resources/superstore_cleaned_with_OrderID.csv", index_col=[0])
df.head()
# Out:
#                    Order ID  Order_Date   Ship_Date     Ship_Mode  \
# 0  CA-2014-AB10015140-41954  2014-11-11  2014-11-13   First Class
# 1    IN-2014-JR162107-41675  2014-02-05  2014-02-07  Second Class
# 2    IN-2014-CR127307-41929  2014-10-17  2014-10-18   First Class
# 3   ES-2014-KM1637548-41667  2014-01-28  2014-01-30   First Class
# 4   SG-2014-RH9495111-41948  2014-11-05  2014-11-06      Same Day
#
#        Segment           City            State        Country          Region  \
# 0     Consumer  Oklahoma City         Oklahoma  United States      Central US
# 1    Corporate     Wollongong  New South Wales      Australia         Oceania
# 2     Consumer       Brisbane       Queensland      Australia         Oceania
# 3  Home Office         Berlin           Berlin        Germany  Western Europe
# 4     Consumer          Dakar            Dakar        Senegal  Western Africa
#
#          Market    Category Sub_Category  \
# 0          USCA  Technology       Phones
# ...

# %% [markdown]
# #### Can we create a model that determines category and subcategory sales based on Order Date?

# %%
# Keep only relevant columns for this analysis
df.drop(df.columns.difference(['Order_Date','Category','Sub_Category', 'Sales']), 1, inplace=True)
# Out:
# /Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
df.dtypes
# Out:
# Order_Date       object
# Category         object
# Sub_Category     object
# Sales           float64
# dtype: object

# %%
# fix date time dtypes in order date
df['Order_Date']= pd.to_datetime(df['Order_Date'])

# %%
df.head()
# Out:
#   Order_Date    Category Sub_Category    Sales
# 0 2014-11-11  Technology       Phones   221.98
# 1 2014-02-05   Furniture       Chairs  3709.40
# 2 2014-10-17  Technology       Phones  5175.17
# 3 2014-01-28  Technology       Phones  2892.51
# 4 2014-11-05  Technology      Copiers  2832.96
