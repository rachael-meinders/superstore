# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import tensorflow as tf
from sklearn.metrics import r2_score
import pandas as pd
import numpy as np

# %%
#  Import and read the file:
df = pd.read_csv("resources/encoded_ss_df.csv", index_col=[0])
df.head()
# Out:
#    City  State  Country  Region  Market    Sales  Quantity  Discount  Profit  \
# 0  2369    754      156       5       4   221.98         2       0.0   62.15
# 1  3532    709        6      12       1  3709.40         9       0.1 -288.77
# 2   499    828        6      12       1  5175.17         9       0.1  919.97
# 3   376    148       54      21       2  2892.51         5       0.1  -96.54
# 4   859    276      124      19       0  2832.96         8       0.0  311.52
#
#    Shipping_Cost  ...  Sub_Category_Storage  Sub_Category_Supplies  \
# 0          40.77  ...                     0                      0
# 1         923.63  ...                     0                      0
# 2         915.49  ...                     0                      0
# 3         910.16  ...                     0                      0
# 4         903.04  ...                     0                      0
#
#    Sub_Category_Tables  Category_Furniture  Category_Office Supplies  \
# 0                    0                   0                         0
# 1                    0                   1                         0
# 2                    0                   0                         0
# 3                    0                   0                         0
# 4                    0                   0                         0
#
#    Category_Technology  Order Priority_Critical  Order Priority_High  \
# 0                    1                        0                    1
# 1                    0                        1                    0
# 2                    1                        0                    0
# 3                    1                        0                    0
# 4                    1                        1                    0
#
#    Order Priority_Low  Order Priority_Medium
# 0                   0                      0
# 1                   0                      0
# 2                   0                      1
# 3                   0                      1
# 4                   0                      0
#
# [5 rows x 47 columns]

# %%
df = df.drop(['City', 'State', 'Country', 'Region','Market'], 1)
df.head()
# Out:
# /Users/forrestcasey/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#      Sales  Quantity  Discount  Profit  Shipping_Cost  order_year  \
# 0   221.98         2       0.0   62.15          40.77        2014
# 1  3709.40         9       0.1 -288.77         923.63        2014
# 2  5175.17         9       0.1  919.97         915.49        2014
# 3  2892.51         5       0.1  -96.54         910.16        2014
# 4  2832.96         8       0.0  311.52         903.04        2014
#
#    order_month  order_day  ship_year  ship_month  ...  Sub_Category_Storage  \
# 0           11         11       2014          11  ...                     0
# 1            2          5       2014           2  ...                     0
# 2           10         17       2014          10  ...                     0
# 3            1         28       2014           1  ...                     0
# 4           11          5       2014          11  ...                     0
#
#    Sub_Category_Supplies  Sub_Category_Tables  Category_Furniture  \
# 0                      0                    0                   0
# 1                      0                    0                   1
# 2                      0                    0                   0
# 3                      0                    0                   0
# 4                      0                    0                   0
#
#    Category_Office Supplies  Category_Technology  Order Priority_Critical  \
# 0                         0                    1                        0
# 1                         0                    0                        1
# 2                         0                    1                        0
# 3                         0                    1                        0
# 4                         0                    1                        1
#
#    Order Priority_High  Order Priority_Low  Order Priority_Medium
# 0                    1                   0                      0
# 1                    0                   0                      0
# 2                    0                   0                      1
# 3                    0                   0                      1
# 4                    0                   0                      0
#
# [5 rows x 42 columns]

# %%
y = df['Sales']
X = df.drop('Sales',axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7
# 50%         -4.920255e-01              8.097916e-01        -5.017866e-01
# 75%         -4.920255e-01              8.097916e-01        -5.017866e-01
# max          2.032415e+00              8.097916e-01         1.992879e+00
#
#        Order Priority_Critical  Order Priority_High  Order Priority_Low  \
# count             1.538700e+04         1.538700e+04        1.538700e+04
# mean             -4.606700e-16        -7.922722e-16        1.785163e-15
# std               1.000032e+00         1.000032e+00        1.000032e+00
# min              -2.901764e-01        -6.521120e-01       -2.268381e-01
# 25%              -2.901764e-01        -6.521120e-01       -2.268381e-01
# 50%              -2.901764e-01        -6.521120e-01       -2.268381e-01
# 75%              -2.901764e-01         1.533479e+00       -2.268381e-01
# max               3.446179e+00         1.533479e+00        4.408431e+00
#
#        Order Priority_Medium
# count           1.538700e+04
# mean           -4.927494e-16
# std             1.000032e+00
# min            -1.163233e+00
# 25%            -1.163233e+00
# 50%             8.596727e-01
# 75%             8.596727e-01
# max             8.596727e-01
#
# [8 rows x 41 columns]

# %%
X_train.columns
# Out:
# Index(['Quantity', 'Discount', 'Profit', 'Shipping_Cost', 'order_year',
#        'order_month', 'order_day', 'ship_year', 'ship_month', 'ship_day',
#        'Ship_Mode_First Class', 'Ship_Mode_Same Day', 'Ship_Mode_Second Class',
#        'Ship_Mode_Standard Class', 'Segment_Consumer', 'Segment_Corporate',
#        'Segment_Home Office', 'Sub_Category_Accessories',
#        'Sub_Category_Appliances', 'Sub_Category_Art', 'Sub_Category_Binders',
#        'Sub_Category_Bookcases', 'Sub_Category_Chairs', 'Sub_Category_Copiers',
#        'Sub_Category_Envelopes', 'Sub_Category_Fasteners',
#        'Sub_Category_Furnishings', 'Sub_Category_Labels',
#        'Sub_Category_Machines', 'Sub_Category_Paper', 'Sub_Category_Phones',
#        'Sub_Category_Storage', 'Sub_Category_Supplies', 'Sub_Category_Tables',
#        'Category_Furniture', 'Category_Office Supplies', 'Category_Technology',
#        'Order Priority_Critical', 'Order Priority_High', 'Order Priority_Low',
#        'Order Priority_Medium'],
#       dtype='object')

# %%
# Training
X_train.shape
# Out:
# (15387, 41)

# %%
inputs = tf.keras.Input(shape=(X_train.shape[1],))
x = tf.keras.layers.Dense(128, activation='relu')(inputs)
x = tf.keras.layers.Dense(128, activation='relu')(x)
outputs = tf.keras.layers.Dense(1,activation='linear')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)
print(model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 41)]              0
#
#  dense_3 (Dense)             (None, 128)               5376
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 22,017
# Trainable params: 22,017
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(
    optimizer='adam',
    loss='mse'
)

history = model.fit(
    X_train,
    y_train,
    valiation_split=0.2,
    batch_size=32,
    epochs=100,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau()
    ]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ys/dtrr5c7x3qg0zys2rj8gf9yw0000gn/T/ipykernel_33714/4190455767.py in <module>
#      16             restore_best_weights=True
#      17         ),
# ---> 18         tf.keras.callbacks.ReduceLROnPlateau()
#      19     ]
#      20 )
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# TypeError: fit() got an unexpected keyword argument 'valiation_split'
