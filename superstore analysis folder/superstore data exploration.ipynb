# %%
# import dependencies
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import tensorflow as tf
from sklearn.metrics import r2_score

# %%
# Import and read the file:
df = pd.read_csv("resources/cleaned_superstore_data.csv")
df.head(3)
# Out:
#    Unnamed: 0  Order_Date   Ship_Date     Ship_Mode    Segment           City  \
# 0           0  2014-11-11  2014-11-13   First Class   Consumer  Oklahoma City
# 1           1  2014-02-05  2014-02-07  Second Class  Corporate     Wollongong
# 2           2  2014-10-17  2014-10-18   First Class   Consumer       Brisbane
#
#              State        Country      Region        Market    Category  \
# 0         Oklahoma  United States  Central US          USCA  Technology
# 1  New South Wales      Australia     Oceania  Asia Pacific   Furniture
# 2       Queensland      Australia     Oceania  Asia Pacific  Technology
#
#   Sub_Category                               Product_Name    Sales  Quantity  \
# 0       Phones                           Samsung Convoy 3   221.98         2
# 1       Chairs  Novimex Executive Leather Armchair, Black  3709.40         9
# 2       Phones          Nokia Smart Phone, with Caller ID  5175.17         9
#
#    Discount  Profit  Shipping_Cost Order Priority
# 0       0.0   62.15          40.77           High
# 1       0.1 -288.77         923.63       Critical
# 2       0.1  919.97         915.49         Medium

# %%
# drop the weird unnamed column that appeared
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.columns
# Out:
# Index(['Order_Date', 'Ship_Date', 'Ship_Mode', 'Segment', 'City', 'State',
#        'Country', 'Region', 'Market', 'Category', 'Sub_Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping_Cost', 'Order Priority'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    Order_Date   Ship_Date     Ship_Mode    Segment           City  \
# 0  2014-11-11  2014-11-13   First Class   Consumer  Oklahoma City
# 1  2014-02-05  2014-02-07  Second Class  Corporate     Wollongong
# 2  2014-10-17  2014-10-18   First Class   Consumer       Brisbane
#
#              State        Country      Region        Market    Category  \
# 0         Oklahoma  United States  Central US          USCA  Technology
# 1  New South Wales      Australia     Oceania  Asia Pacific   Furniture
# 2       Queensland      Australia     Oceania  Asia Pacific  Technology
#
#   Sub_Category                               Product_Name    Sales  Quantity  \
# 0       Phones                           Samsung Convoy 3   221.98         2
# 1       Chairs  Novimex Executive Leather Armchair, Black  3709.40         9
# 2       Phones          Nokia Smart Phone, with Caller ID  5175.17         9
#
#    Discount  Profit  Shipping_Cost Order Priority
# 0       0.0   62.15          40.77           High
# 1       0.1 -288.77         923.63       Critical
# 2       0.1  919.97         915.49         Medium

# %%
# get year month day into different columns, because why not?
df['order_year'] = pd.DatetimeIndex(df['Order_Date']).year
df['order_month'] = pd.DatetimeIndex(df['Order_Date']).month
df['order_day'] = pd.DatetimeIndex(df['Order_Date']).day

df['ship_year'] = pd.DatetimeIndex(df['Ship_Date']).year
df['ship_month'] = pd.DatetimeIndex(df['Ship_Date']).month
df['ship_day'] = pd.DatetimeIndex(df['Ship_Date']).day

df = df.drop(['Order_Date','Ship_Date'], axis=1)
df.head(3)
# Out:
#       Ship_Mode    Segment           City            State        Country  \
# 0   First Class   Consumer  Oklahoma City         Oklahoma  United States
# 1  Second Class  Corporate     Wollongong  New South Wales      Australia
# 2   First Class   Consumer       Brisbane       Queensland      Australia
#
#        Region        Market    Category Sub_Category  \
# 0  Central US          USCA  Technology       Phones
# 1     Oceania  Asia Pacific   Furniture       Chairs
# 2     Oceania  Asia Pacific  Technology       Phones
#
#                                 Product_Name  ...  Discount  Profit  \
# 0                           Samsung Convoy 3  ...       0.0   62.15
# 1  Novimex Executive Leather Armchair, Black  ...       0.1 -288.77
# 2          Nokia Smart Phone, with Caller ID  ...       0.1  919.97
#
#    Shipping_Cost  Order Priority  order_year order_month  order_day  \
# 0          40.77            High        2014          11         11
# 1         923.63        Critical        2014           2          5
# 2         915.49          Medium        2014          10         17
#
#    ship_year  ship_month  ship_day
# 0       2014          11        13
# 1       2014           2         7
# 2       2014          10        18
#
# [3 rows x 22 columns]

# %%
pd.get_dummies(df['Ship_Mode'], prefix = 'Ship_Mode')
# Out:
#        Ship_Mode_First Class  Ship_Mode_Same Day  Ship_Mode_Second Class  \
# 0                          1                   0                       0
# 1                          0                   0                       1
# 2                          1                   0                       0
# 3                          1                   0                       0
# 4                          0                   1                       0
# ...                      ...                 ...                     ...
# 51285                      0                   1                       0
# 51286                      0                   0                       0
# 51287                      0                   0                       1
# 51288                      0                   0                       0
# 51289                      0                   0                       1
#
#        Ship_Mode_Standard Class
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 51285                         0
# 51286                         1
# 51287                         0
# 51288                         1
# 51289                         0
#
# [51290 rows x 4 columns]

# %%
def onehot_encode(df, column):
    df = df.copy()
    dummies = pd.get_dummies(df[column],prefix=column)
    df = pd.concat([df, dummies],axis=1)
    df = df.drop(column,axis=1)
    return df

# %%
# One hot encode categorical features
for column in 

return df
