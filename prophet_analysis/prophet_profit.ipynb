# %%
# import dependencies
import pandas as pd
from prophet import Prophet

# %% [markdown]
# ## All Orders

# %%
# import Superstore (all orders)
super_df = pd.read_csv('../resources/superstore.csv')
super_df.head()
# Out:
#                    Order ID  Order Date   Ship Date     Ship Mode  \
# 0  CA-2014-AB10015140-41954  2014-11-11  2014-11-13   First Class
# 1    IN-2014-JR162107-41675  2014-02-05  2014-02-07  Second Class
# 2    IN-2014-CR127307-41929  2014-10-17  2014-10-18   First Class
# 3   ES-2014-KM1637548-41667  2014-01-28  2014-01-30   First Class
# 4   SG-2014-RH9495111-41948  2014-11-05  2014-11-06      Same Day
#
#        Segment           City            State        Country          Region  \
# 0     Consumer  Oklahoma City         Oklahoma  United States      Central US
# 1    Corporate     Wollongong  New South Wales      Australia         Oceania
# 2     Consumer       Brisbane       Queensland      Australia         Oceania
# 3  Home Office         Berlin           Berlin        Germany  Western Europe
# 4     Consumer          Dakar            Dakar        Senegal  Western Africa
#
#          Market  ...    Sales Quantity  Discount  Profit  Shipping Cost  \
# ...

# %%
# Create a new df with only the order date & profit $ amount - then rename to ds and y, respectively
profit = super_df[['Order Date', 'Profit']]
profit = profit.rename(columns={'Order Date': 'ds', 'Profit': 'y'})
profit.head()
# Out:
#            ds       y
# 0  2014-11-11   62.15
# 1  2014-02-05 -288.77
# 2  2014-10-17  919.97
# 3  2014-01-28  -96.54
# 4  2014-11-05  311.52

# %%
# initiate new Prophet object
m = Prophet()

# %%
#call Prophet fit method and pass in the profit df
m.fit(profit)
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# extend our date range into the future by 365 days
# includes all current date and extends our data through end of 2016
future_profit = m.make_future_dataframe(periods=365)
future_profit.tail()
# Out:
#              ds
# 1790 2016-12-26
# 1791 2016-12-27
# 1792 2016-12-28
# 1793 2016-12-29
# 1794 2016-12-30

# %%
# create predicted profit values (yhat) as well as lower & upper values for uncertainty intervals
forecast_profit = m.predict(future_profit)
forecast_profit[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 1790 2016-12-26  21.558861 -183.130612  268.182005
# 1791 2016-12-27  19.098844 -215.712705  248.877624
# 1792 2016-12-28  18.860503 -198.230320  272.629104
# 1793 2016-12-29  18.979650 -193.242363  236.752408
# 1794 2016-12-30  23.658554 -206.466979  256.664613

# %%
# plot the predicted profit values
pred_profit = m.plot(forecast_profit)

# %%
# plot the forecast components - overall trend, yearly seasonality, & weekly seasonality
pred_profit_components = m.plot_components(forecast_profit)

# %% [markdown]
# ## Orders from Top Countries

# %%
# import superstore (top countries)
super_topcountries = pd.read_csv('../resources/superstore_topcountries.csv')
super_topcountries.head()
# Out:
#                    Order ID  Order Date   Ship Date     Ship Mode  \
# 0  CA-2014-AB10015140-41954  2014-11-11  2014-11-13   First Class
# 1    IN-2014-JR162107-41675  2014-02-05  2014-02-07  Second Class
# 2    IN-2014-CR127307-41929  2014-10-17  2014-10-18   First Class
# 3   ES-2014-KM1637548-41667  2014-01-28  2014-01-30   First Class
# 4    IN-2014-JM156557-41818  2014-06-28  2014-07-01  Second Class
#
#        Segment           City            State        Country          Region  \
# 0     Consumer  Oklahoma City         Oklahoma  United States      Central US
# 1    Corporate     Wollongong  New South Wales      Australia         Oceania
# 2     Consumer       Brisbane       Queensland      Australia         Oceania
# 3  Home Office         Berlin           Berlin        Germany  Western Europe
# 4    Corporate         Sydney  New South Wales      Australia         Oceania
#
#          Market  ... Quantity Discount  Profit  Shipping Cost  Order Priority  \
# ...

# %%
# Create a new df with only the order date & profit $ amount - then rename to ds and y, respectively
top_profit = super_topcountries[['Order Date', 'Profit']]
top_profit = top_profit.rename(columns={'Order Date': 'ds', 'Profit': 'y'})
top_profit.head()
# Out:
#            ds       y
# 0  2014-11-11   62.15
# 1  2014-02-05 -288.77
# 2  2014-10-17  919.97
# 3  2014-01-28  -96.54
# 4  2014-06-28  763.28

# %%
# initiate new Prophet object
m = Prophet()

# %%
#call Prophet fit method and pass in the top_profit df
m.fit(top_profit)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# extend our date range into the future by 365 days
# includes all current date and extends our data through end of 2016
future_top_profit = m.make_future_dataframe(periods=365)
future_top_profit.tail()
# Out:
#              ds
# 1772 2016-12-26
# 1773 2016-12-27
# 1774 2016-12-28
# 1775 2016-12-29
# 1776 2016-12-30

# %%
# create predicted profit values (yhat) as well as lower & upper values for uncertainty intervals
forecast_top_profit = m.predict(future_top_profit)
forecast_top_profit[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 1772 2016-12-26  26.457087 -210.729407  265.649889
# 1773 2016-12-27  21.829503 -214.216316  267.778488
# 1774 2016-12-28  21.422508 -200.916469  264.095913
# 1775 2016-12-29  21.043705 -202.785825  260.212011
# 1776 2016-12-30  25.399400 -197.981359  249.291860

# %%
# plot the predicted profit values
pred_top_profit = m.plot(forecast_top_profit)

# %%
# plot the forecast components - overall trend, yearly seasonality, & weekly seasonality
pred_top_profit_components = m.plot_components(forecast_top_profit)
