# %%
# import dependencies
import pandas as pd
from prophet import Prophet

# %% [markdown]
# ## All Orders

# %%
# import Superstore (all orders)
super_df = pd.read_csv('../resources/superstore.csv')
super_df.head()
# Out:
#                    Order ID  Order Date   Ship Date     Ship Mode  \
# 0  CA-2014-AB10015140-41954  2014-11-11  2014-11-13   First Class
# 1    IN-2014-JR162107-41675  2014-02-05  2014-02-07  Second Class
# 2    IN-2014-CR127307-41929  2014-10-17  2014-10-18   First Class
# 3   ES-2014-KM1637548-41667  2014-01-28  2014-01-30   First Class
# 4   SG-2014-RH9495111-41948  2014-11-05  2014-11-06      Same Day
#
#        Segment           City            State        Country          Region  \
# 0     Consumer  Oklahoma City         Oklahoma  United States      Central US
# 1    Corporate     Wollongong  New South Wales      Australia         Oceania
# 2     Consumer       Brisbane       Queensland      Australia         Oceania
# 3  Home Office         Berlin           Berlin        Germany  Western Europe
# 4     Consumer          Dakar            Dakar        Senegal  Western Africa
#
#          Market  ...    Sales Quantity  Discount  Profit  Shipping Cost  \
# ...

# %%
# Create a new df with only the order date & returned $ amount - then rename to ds and y, respectively
returned_amt = super_df[['Order Date', 'Returned $ Amount']]
returned_amt = returned_amt.rename(columns={'Order Date': 'ds', 'Returned $ Amount': 'y'})
returned_amt.head()
# Out:
#            ds    y
# 0  2014-11-11  0.0
# 1  2014-02-05  0.0
# 2  2014-10-17  0.0
# 3  2014-01-28  0.0
# 4  2014-11-05  0.0

# %%
# initiate new Prophet object
m = Prophet()

# %%
#call Prophet fit method and pass in the returned_amt df
m.fit(returned_amt)
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# extend our date range into the future by 365 days
# includes all current date and extends our data through end of 2016
future_returned_amt = m.make_future_dataframe(periods=365)
future_returned_amt.tail()
# Out:
#              ds
# 1790 2016-12-26
# 1791 2016-12-27
# 1792 2016-12-28
# 1793 2016-12-29
# 1794 2016-12-30

# %%
# create predicted returned$ values (yhat) as well as lower & upper values for uncertainty intervals
forecast_returned_amt = m.predict(future_returned_amt)
forecast_returned_amt[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 1790 2016-12-26  16.463486 -124.193127  150.843625
# 1791 2016-12-27  14.179260 -123.292281  154.544238
# 1792 2016-12-28  16.035301 -126.817085  152.915258
# 1793 2016-12-29  15.478735 -118.630624  149.480524
# 1794 2016-12-30  15.021930 -127.973042  151.196274

# %%
# plot the predicted returned$ values
pred_returned_amt = m.plot(forecast_returned_amt)

# %%
# plot the forecast components - overall trend, yearly seasonality, & weekly seasonality
pred_returned_amt_components = m.plot_components(forecast_returned_amt)

# %% [markdown]
# ## Orders from Top Countries

# %%
# import superstore (top countries)
super_topcountries = pd.read_csv('../resources/superstore_topcountries.csv')
super_topcountries.head()
# Out:
#                    Order ID  Order Date   Ship Date     Ship Mode  \
# 0  CA-2014-AB10015140-41954  2014-11-11  2014-11-13   First Class
# 1    IN-2014-JR162107-41675  2014-02-05  2014-02-07  Second Class
# 2    IN-2014-CR127307-41929  2014-10-17  2014-10-18   First Class
# 3   ES-2014-KM1637548-41667  2014-01-28  2014-01-30   First Class
# 4    IN-2014-JM156557-41818  2014-06-28  2014-07-01  Second Class
#
#        Segment           City            State        Country          Region  \
# 0     Consumer  Oklahoma City         Oklahoma  United States      Central US
# 1    Corporate     Wollongong  New South Wales      Australia         Oceania
# 2     Consumer       Brisbane       Queensland      Australia         Oceania
# 3  Home Office         Berlin           Berlin        Germany  Western Europe
# 4    Corporate         Sydney  New South Wales      Australia         Oceania
#
#          Market  ... Quantity Discount  Profit  Shipping Cost  Order Priority  \
# ...

# %%
# Create a new df with only the order date & profit $ amount - then rename to ds and y, respectively
top_returned_amt = super_df[['Order Date', 'Returned $ Amount']]
top_returned_amt = top_returned_amt.rename(columns={'Order Date': 'ds', 'Returned $ Amount': 'y'})
top_returned_amt.head()
# Out:
#            ds    y
# 0  2014-11-11  0.0
# 1  2014-02-05  0.0
# 2  2014-10-17  0.0
# 3  2014-01-28  0.0
# 4  2014-11-05  0.0

# %%
# initiate new Prophet object
m = Prophet()

# %%
#call Prophet fit method and pass in the top_profit df
m.fit(top_returned_amt)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# extend our date range into the future by 365 days
# includes all current date and extends our data through end of 2016
future_top_returned_amt = m.make_future_dataframe(periods=365)
future_top_returned_amt.tail()
# Out:
#              ds
# 1790 2016-12-26
# 1791 2016-12-27
# 1792 2016-12-28
# 1793 2016-12-29
# 1794 2016-12-30

# %%
# create predicted returned_amt values (yhat) as well as lower & upper values for uncertainty intervals
forecast_top_returned_amt = m.predict(future_top_returned_amt)
forecast_top_returned_amt[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 1790 2016-12-26  16.463486 -120.052894  160.811895
# 1791 2016-12-27  14.179260 -127.849199  154.275185
# 1792 2016-12-28  16.035301 -122.784164  157.789315
# 1793 2016-12-29  15.478735 -118.747414  155.212264
# 1794 2016-12-30  15.021930 -119.580770  159.225249

# %%
# plot the predicted returned_amt values
pred_top_returned_amt = m.plot(forecast_top_returned_amt)

# %%
# plot the forecast components - overall trend, yearly seasonality, & weekly seasonality
pred_top_returned_amt_components = m.plot_components(forecast_top_returned_amt)
