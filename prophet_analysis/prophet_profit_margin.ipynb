# %%
# import dependencies
import pandas as pd
from prophet import Prophet

# %% [markdown]
# ## All Orders

# %%
# import Superstore (all orders)
super_df = pd.read_csv('../resources/superstore.csv')
super_df.head()
# Out:
#                    Order ID  Order Date   Ship Date     Ship Mode  \
# 0  CA-2014-AB10015140-41954  2014-11-11  2014-11-13   First Class
# 1    IN-2014-JR162107-41675  2014-02-05  2014-02-07  Second Class
# 2    IN-2014-CR127307-41929  2014-10-17  2014-10-18   First Class
# 3   ES-2014-KM1637548-41667  2014-01-28  2014-01-30   First Class
# 4   SG-2014-RH9495111-41948  2014-11-05  2014-11-06      Same Day
#
#        Segment           City            State        Country          Region  \
# 0     Consumer  Oklahoma City         Oklahoma  United States      Central US
# 1    Corporate     Wollongong  New South Wales      Australia         Oceania
# 2     Consumer       Brisbane       Queensland      Australia         Oceania
# 3  Home Office         Berlin           Berlin        Germany  Western Europe
# 4     Consumer          Dakar            Dakar        Senegal  Western Africa
#
#          Market  ...    Sales Quantity  Discount  Profit  Shipping Cost  \
# ...

# %%
# Create a new df with only the order date & profit margin - then rename to ds and y, respectively
profit_marg = super_df[['Order Date', 'Profit Margin Percentage']]
profit_marg = profit_marg.rename(columns={'Order Date': 'ds', 'Profit Margin Percentage': 'y'})
profit_marg.head()
# Out:
#            ds          y
# 0  2014-11-11  27.998018
# 1  2014-02-05  -7.784817
# 2  2014-10-17  17.776614
# 3  2014-01-28  -3.337586
# 4  2014-11-05  10.996272

# %%
# initiate new Prophet object
m = Prophet()

# %%
#call Prophet fit method and pass in the profit_marg df
m.fit(profit_marg)
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# extend our date range into the future by 365 days
# includes all current date and extends our data through end of 2016
future_profit_marg = m.make_future_dataframe(periods=365)
future_profit_marg.tail()
# Out:
#              ds
# 1790 2016-12-26
# 1791 2016-12-27
# 1792 2016-12-28
# 1793 2016-12-29
# 1794 2016-12-30

# %%
# create predicted profit margin values (yhat) as well as lower & upper values for uncertainty intervals
forecast_profit_marg = m.predict(future_profit_marg)
forecast_profit_marg[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 1790 2016-12-26  4.839432  -54.623815   61.154789
# 1791 2016-12-27  0.778804  -58.697972   58.965756
# 1792 2016-12-28  1.143030  -53.946804   60.566179
# 1793 2016-12-29  0.777169  -57.294576   55.688776
# 1794 2016-12-30  1.916106  -60.507007   59.467255

# %%
# plot the predicted profit margin values
pred_profit_marg = m.plot(forecast_profit_marg)

# %%
# plot the forecast components - overall trend, yearly seasonality, & weekly seasonality
pred_profit_marg_components = m.plot_components(forecast_profit_marg)

# %% [markdown]
# ## Orders from Top Countries

# %%
# import superstore (top countries)
super_topcountries = pd.read_csv('../resources/superstore_topcountries.csv')
super_topcountries.head()
# Out:
#                    Order ID  Order Date   Ship Date     Ship Mode  \
# 0  CA-2014-AB10015140-41954  2014-11-11  2014-11-13   First Class
# 1    IN-2014-JR162107-41675  2014-02-05  2014-02-07  Second Class
# 2    IN-2014-CR127307-41929  2014-10-17  2014-10-18   First Class
# 3   ES-2014-KM1637548-41667  2014-01-28  2014-01-30   First Class
# 4    IN-2014-JM156557-41818  2014-06-28  2014-07-01  Second Class
#
#        Segment           City            State        Country          Region  \
# 0     Consumer  Oklahoma City         Oklahoma  United States      Central US
# 1    Corporate     Wollongong  New South Wales      Australia         Oceania
# 2     Consumer       Brisbane       Queensland      Australia         Oceania
# 3  Home Office         Berlin           Berlin        Germany  Western Europe
# 4    Corporate         Sydney  New South Wales      Australia         Oceania
#
#          Market  ... Quantity Discount  Profit  Shipping Cost  Order Priority  \
# ...

# %%
# Create a new df with only the order date & profit margin % - then rename to ds and y, respectively
top_profit_marg = super_topcountries[['Order Date', 'Profit Margin Percentage']]
top_profit_marg = top_profit_marg.rename(columns={'Order Date': 'ds', 'Profit Margin Percentage': 'y'})
top_profit_marg.head()
# Out:
#            ds          y
# 0  2014-11-11  27.998018
# 1  2014-02-05  -7.784817
# 2  2014-10-17  17.776614
# 3  2014-01-28  -3.337586
# 4  2014-06-28  26.663127

# %%
# initiate new Prophet object
m = Prophet()

# %%
#call Prophet fit method and pass in the top_profit_marg df
m.fit(top_profit_marg)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# extend our date range into the future by 365 days
# includes all current date and extends our data through end of 2016
future_top_profit_marg = m.make_future_dataframe(periods=365)
future_top_profit_marg.tail()
# Out:
#              ds
# 1772 2016-12-26
# 1773 2016-12-27
# 1774 2016-12-28
# 1775 2016-12-29
# 1776 2016-12-30

# %%
# create predicted profit margin values (yhat) as well as lower & upper values for uncertainty intervals
forecast_top_profit_marg = m.predict(future_top_profit_marg)
forecast_top_profit_marg[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 1772 2016-12-26  7.983430  -50.779492   69.094654
# 1773 2016-12-27  3.401307  -56.959411   62.219866
# 1774 2016-12-28  3.616350  -52.366826   62.086300
# 1775 2016-12-29  3.191422  -57.753606   64.012059
# 1776 2016-12-30  4.927403  -53.485671   66.428505

# %%
# plot the predicted profit values
pred_top_profit_marg = m.plot(forecast_top_profit_marg)

# %%
# plot the forecast components - overall trend, yearly seasonality, & weekly seasonality
pred_top_profit_marg_components = m.plot_components(forecast_top_profit_marg)
