# %%
import pandas as pd

df = pd.read_csv("global_superstore_orders_2016.csv")

# %%
# Preview Data

df.head()
# Out:
#    Row ID                  Order ID  Order Date   Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954  11/11/2014  11/13/2014   First Class
# 1   26341    IN-2014-JR162107-41675    2/5/2014    2/7/2014  Second Class
# 2   25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014   First Class
# 3   13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014   First Class
# 4   47221   SG-2014-RH9495111-41948   11/5/2014   11/6/2014      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
# Remove "$" from all columns using USD

df['Sales'] = df['Sales'].str.replace('$',"")
df['Profit'] = df['Profit'].str.replace('$',"")
df['Shipping Cost'] = df['Shipping Cost'].replace('$',"")

# Confirm "$" was removed

df.head()
# Out:
# <ipython-input-3-7ab4484bd52f>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Sales'] = df['Sales'].str.replace('$',"")
# <ipython-input-3-7ab4484bd52f>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Profit'] = df['Profit'].str.replace('$',"")
#    Row ID                  Order ID  Order Date   Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954  11/11/2014  11/13/2014   First Class
# 1   26341    IN-2014-JR162107-41675    2/5/2014    2/7/2014  Second Class
# 2   25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014   First Class
# 3   13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014   First Class
# ...

# %%
# Remove "," from all numeric columns

df['Sales'] = df['Sales'].str.replace(',',"")
df['Profit'] = df['Profit'].str.replace(',',"")
df['Shipping Cost'] = df['Shipping Cost'].replace(',',"")

# Confirm "," was removed

df.head()
# Out:
#    Row ID                  Order ID  Order Date   Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954  11/11/2014  11/13/2014   First Class
# 1   26341    IN-2014-JR162107-41675    2/5/2014    2/7/2014  Second Class
# 2   25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014   First Class
# 3   13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014   First Class
# 4   47221   SG-2014-RH9495111-41948   11/5/2014   11/6/2014      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
# Convert cleaned string values to numeric

df['Sales'] = pd.to_numeric(df['Sales'])
df['Profit'] = pd.to_numeric(df['Profit'])
df['Shipping Cost'] = pd.to_numeric(df['Shipping Cost'])

# %%
# Drop columns with least signifigance to hypothesis

df.drop(['Order ID', 'Order Date', 'Ship Date', 'Customer ID', 'Postal Code'], axis = 1, inplace = True)

df.head()
# Out:
#    Row ID     Ship Mode     Customer Name      Segment           City  \
# 0   40098   First Class     Aaron Bergman     Consumer  Oklahoma City
# 1   26341  Second Class     Justin Ritter    Corporate     Wollongong
# 2   25330   First Class      Craig Reiter     Consumer       Brisbane
# 3   13524   First Class  Katherine Murray  Home Office         Berlin
# 4   47221      Same Day       Rick Hansen     Consumer          Dakar
#
#              State        Country          Region        Market   Product ID  \
# 0         Oklahoma  United States      Central US          USCA  TEC-PH-5816
# 1  New South Wales      Australia         Oceania  Asia Pacific  FUR-CH-5379
# 2       Queensland      Australia         Oceania  Asia Pacific  TEC-PH-5356
# 3           Berlin        Germany  Western Europe        Europe  TEC-PH-5267
# 4            Dakar        Senegal  Western Africa        Africa  TEC-CO-6011
#
#      Category Sub-Category                               Product Name  \
# ...

# %%
# Drop Rows with null values

# df.dropna()

df.isnull().sum(axis = 0)
# Out:
# Row ID            0
# Ship Mode         0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Region            0
# Market            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
# Add Profit Margin Column

df['Profit Margin Percentage']=df.apply(lambda x: x.Profit/x.Sales if x.Profit!=0 else 0, axis=1) * 100

df['Shipping Cost'] = pd.to_numeric(df['Shipping Cost'])

df.head()
# Out:
#    Row ID     Ship Mode     Customer Name      Segment           City  \
# 0   40098   First Class     Aaron Bergman     Consumer  Oklahoma City
# 1   26341  Second Class     Justin Ritter    Corporate     Wollongong
# 2   25330   First Class      Craig Reiter     Consumer       Brisbane
# 3   13524   First Class  Katherine Murray  Home Office         Berlin
# 4   47221      Same Day       Rick Hansen     Consumer          Dakar
#
#              State        Country          Region        Market   Product ID  \
# 0         Oklahoma  United States      Central US          USCA  TEC-PH-5816
# 1  New South Wales      Australia         Oceania  Asia Pacific  FUR-CH-5379
# 2       Queensland      Australia         Oceania  Asia Pacific  TEC-PH-5356
# 3           Berlin        Germany  Western Europe        Europe  TEC-PH-5267
# 4            Dakar        Senegal  Western Africa        Africa  TEC-CO-6011
#
#      Category Sub-Category                               Product Name  \
# ...

# %%
# Raw Average Sale

df["Sales"].mean()
# Out:
# 246.49068531878765

# %%
# Average Sale Price by Category

df[["Category", "Sales"]].groupby("Category").mean()
# Out:
#                       Sales
# Category
# Furniture        416.881646
# Office Supplies  121.048786
# Technology       467.859063

# %%
# Average Sales Price by Sub-Category

df.groupby(['Category', 'Sub-Category'])['Sales'].mean()
df.dtypes
# Out:
# Row ID                        int64
# Ship Mode                    object
# Customer Name                object
# Segment                      object
# City                         object
# State                        object
# Country                      object
# Region                       object
# Market                       object
# Product ID                   object
# Category                     object
# Sub-Category                 object
# Product Name                 object
# Sales                       float64
# Quantity                      int64
# Discount                    float64
# Profit                      float64
# Shipping Cost               float64
# Order Priority               object
# Profit Margin Percentage    float64
# dtype: object

# %%
#df.groupby(['Category', 'Sub-Category'])['Profit Margin Percentage'].mean()

df.groupby(['Category','Sub-Category'])['Profit Margin Percentage'].mean()
# Out:
# Category         Sub-Category
# Furniture        Bookcases        1.488165
#                  Chairs           2.477528
#                  Furnishings      5.390950
#                  Tables         -24.204800
# Office Supplies  Appliances      -0.198507
#                  Art              6.485630
#                  Binders         -0.172981
#                  Envelopes        8.292237
#                  Fasteners        7.312973
#                  Labels          11.930966
#                  Paper           19.371858
#                  Storage          1.261661
#                  Supplies         4.412333
# Technology       Accessories      8.705600
#                  Copiers          7.167309
#                  Machines        -4.350493
#                  Phones           4.213040
# Name: Profit Margin Percentage, dtype: float64
